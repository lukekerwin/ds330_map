# %%
import pandas as pd
data = pd.read_csv('UberDatasetFiltered.csv')

# %%
# Convert times to just the hour
data['START_DATE'] = pd.to_datetime(data['START_DATE']).dt.hour
data['END_DATE'] = pd.to_datetime(data['END_DATE']).dt.hour
data
# Out:
#      START_DATE  END_DATE  CATEGORY        START         STOP  MILES  \
# 0            13        13  Business         Cary         Cary    0.8
# 1             8         8  Business         Cary  Morrisville    8.3
# 2            12        12  Business      Jamaica     New York   16.5
# 3            18        18  Business     Elmhurst     New York    7.5
# 4            19        19  Business      Midtown  East Harlem    6.2
# ..          ...       ...       ...          ...          ...    ...
# 340          18        18  Business         Cary         Cary    4.2
# 341          20        20  Business         Cary         Cary    4.1
# 342          17        18  Business         Cary  Morrisville    3.0
# 343          20        20  Business  Morrisville         Cary    3.1
# 344          14        14  Business         Cary  Morrisville   10.6
#
#              PURPOSE     START_STATE      STOP_STATE  \
# 0            Meeting  North Carolina  North Carolina
# ...
